# %%
#load the saved model and check predictions
from keras.models import Model, load_model
from keras.layers import Input
import numpy as np
import csv
# Out:
# Using TensorFlow backend.

# %%
#form input_texts
input_texts = []
with open('with_date(copy).csv') as csvfile:
    next(csvfile)
    readCSV = csv.reader(csvfile,delimiter=',')
    for row in readCSV:
        text = " ".join(row)
        input_texts.append(text)
#input_texts

# %%
#form output_texts
with open('description.txt','r',encoding='utf-8') as f:
    lines =   f.read().split('\n') 
target_texts = []
for line in lines:
    line = 'START_ ' + line + ' _END'
    target_texts.append(line)
#target_texts

# %%
input_words = set()
target_words = set()
for input_text,target_text in zip(input_texts,target_texts):
    words = input_text.split(' ') 
    for word in words:
        if word not in input_words:
            input_words.add(word)
    words = target_text.split(' ') 
    for word in words:
        if word not in target_words:
            target_words.add(word)
input_words = sorted(list(input_words))
target_words = sorted(list(target_words))
num_encoder_tokens = len(input_words)
num_decoder_tokens = len(target_words)
input_text_sizes = []
for text in input_texts:
    input_text_sizes.append(len(text.split(' ')))
target_text_sizes = []
for text in target_texts:
    target_text_sizes.append(len(text.split(' ')))
max_encoder_seq_length = max(input_text_sizes)
max_decoder_seq_length = max(target_text_sizes)

# %%
input_token_index = dict(
    [(word, i) for i, word in enumerate(input_words)])
target_token_index = dict(
    [(word, i) for i, word in enumerate(target_words)])

# %%
encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length),
    dtype='float32')
for i,(input_text,target_text) in enumerate(zip(input_texts,target_texts)):
    for t, word in enumerate(input_text.split(' ')):
        encoder_input_data[i,t]=input_token_index[word]

# %%
model = load_model('s2s.h5')
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None)         0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, None)         0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 50)     773550      input_1[0][0]
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, None, 50)     774350      input_2[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 50), (None,  20200       embedding_1[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, None, 50), ( 20200       embedding_2[0][0]
#                                                                  lstm_1[0][1]
#                                                                  lstm_1[0][2]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, None, 15487)  789837      lstm_2[0][0]
# ==================================================================================================
# Total params: 2,378,137
# Trainable params: 2,378,137
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
encoder_inputs = model.input[0]
encoder_outputs,state_h_enc,state_c_enc = model.layers[4].output
encoder_states = [state_h_enc,state_c_enc]
encoder_model = Model(encoder_inputs, encoder_states)

# %%
decoder_state_input_h = Input(shape=(50,))
decoder_state_input_c = Input(shape=(50,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

decoder_inputs = model.input[1]

dex=  model.layers[3]

final_dex2= dex(decoder_inputs)

decoder_lstm = model.layers[5]
decoder_outputs2, state_h2, state_c2 = decoder_lstm(final_dex2, initial_state=decoder_states_inputs)
decoder_states2 = [state_h2, state_c2]
decoder_dense = model.layers[6]
decoder_outputs2 = decoder_dense(decoder_outputs2)
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs2] + decoder_states2)

# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict(
    (i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict(
    (i, char) for char, i in target_token_index.items())

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)
    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0] = target_token_index['START_']

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict(
            [target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += ' '+sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if (sampled_char == '_END' or
           len(decoded_sentence) > 200):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # Update states
        states_value = [h, c]

    return decoded_sentence

# %%
for seq_index in range(1000,1050):
    input_seq = encoder_input_data[seq_index: seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print('-')
    print('Input sentence:', input_texts[seq_index: seq_index + 1])
    print('Decoded sentence:', decoded_sentence)
# Out:
# -
# Input sentence: ['1000 1001 5121 Credit 811 0 India US USD 0.12 2009-05-24']
# Decoded sentence:  Transaction no 1001 is a credit transaction,performed on 2009-05-24, from India to US worth 811 dollars, which is suspicious with 0.12 probability. _END
# -
# Input sentence: ['1001 1002 5140 Credit 6564 1 Pakistan Germany Euro 0.7 2011-01-13']
# Decoded sentence:  Transaction no 1002 is a credit transaction,performed on 2011-01-13, from Pakistan to Germany worth 6564 euros, which is not suspicious with 0.7 probability. _END
# -
# Input sentence: ['1002 1003 5470 Credit 606 0 India India INR 0.95 2021-07-17']
# Decoded sentence:  Transaction no 1003 is a credit transaction,performed on 2021-07-17, within India worth 606 ruppees, which is suspicious with 0.95 probability. _END
# -
# Input sentence: ['1003 1004 5058 Debit 671 0 Pakistan Japan Euro 0.38 2017-07-06']
# Decoded sentence:  Transaction no 1004 is a debit transaction,performed on 2017-07-06, from Pakistan to Japan worth 671 euros, which is suspicious with 0.38 probability. _END
# -
# Input sentence: ['1004 1005 5483 Debit 7750 0 US India INR 0.28 2009-04-11']
# Decoded sentence:  Transaction no 1005 is a debit transaction,performed on 2009-04-11, from US to India worth 7750 ruppees, which is suspicious with 0.28 probability. _END
# -
# Input sentence: ['1005 1006 5403 Credit 6788 1 India India INR 0.7 2020-08-25']
# Decoded sentence:  Transaction no 1006 is a credit transaction,performed on 2020-08-25, within India worth 6788 ruppees, which is not suspicious with 0.7 probability. _END
# -
# Input sentence: ['1006 1007 5261 Debit 5481 0 Japan China Yen 0.21 2007-12-17']
# Decoded sentence:  Transaction no 1007 is a debit transaction,performed on 2007-12-17, from Japan to China worth 5481 yen, which is suspicious with 0.21 probability. _END
# -
# Input sentence: ['1007 1008 5142 Credit 1330 0 Pakistan US USD 0.57 2024-08-11']
# Decoded sentence:  Transaction no 1008 is a credit transaction,performed on 2006-11-24, from Pakistan to 5106 worth 7712 6281 3598 from Pakistan 2010-02-09, dollars, which is not suspicious with 0.83 probability. _END
# -
# Input sentence: ['1008 1009 5138 Credit 1056 0 India Germany INR 0.04 2011-12-20']
# Decoded sentence:  Transaction no 1009 is a credit transaction,performed on 2011-12-20, from India to Germany worth 1056 ruppees, which is suspicious with 0.04 probability. _END
# -
# Input sentence: ['1009 1010 5463 Credit 5514 0 Pakistan India INR 0.11 2010-03-17']
# Decoded sentence:  Transaction no 1010 is a credit transaction,performed on 2010-03-17, from Pakistan to India worth 5514 ruppees, which is suspicious with 0.11 probability. _END
# -
# Input sentence: ['1010 1011 5020 Credit 1479 1 India US USD 0.65 2005-03-11']
# Decoded sentence:  Transaction no 1011 is a credit transaction,performed on 2005-03-11, from India to US worth 1479 dollars, which is not suspicious with 0.65 probability. _END
# -
# Input sentence: ['1011 1012 5222 Debit 2812 1 Pakistan Germany Euro 0.5 2023-04-14']
# Decoded sentence:  Transaction no 1012 is a debit transaction,performed on 2023-04-14, from Pakistan to Germany worth 2812 euros, which is not suspicious with 0.5 probability. _END
# -
# Input sentence: ['1012 1013 5078 Credit 5623 0 India India INR 0.99 2005-11-15']
# Decoded sentence:  Transaction no 1013 is a credit transaction,performed on 2005-11-15, within India worth 5623 ruppees, which is suspicious with 0.99 probability. _END
# -
# Input sentence: ['1013 1014 5412 Credit 2259 1 Pakistan Japan Euro 0.74 2021-03-16']
# Decoded sentence:  Transaction no 1014 is a credit transaction,performed on 2021-03-16, from Pakistan to Japan worth 2259 euros, which is not suspicious with 0.74 probability. _END
# -
# Input sentence: ['1014 1015 5345 Credit 9627 0 US India INR 0.33 2011-04-06']
# Decoded sentence:  Transaction no 1015 is a credit transaction,performed on 2011-04-06, from US to India worth 9627 ruppees, which is suspicious with 0.33 probability. _END
# -
# Input sentence: ['1015 1016 5240 Credit 8403 0 India India INR 0.46 2009-10-06']
# Decoded sentence:  Transaction no 1016 is a credit transaction,performed on 2009-10-06, within India worth 8403 ruppees, which is suspicious with 0.46 probability. _END
# -
# Input sentence: ['1016 1017 5278 Debit 6040 0 Japan China Yen 0.3 2010-09-05']
# Decoded sentence:  Transaction no 1017 is a debit transaction,performed on 2010-09-05, from Japan to China worth 6040 yen, which is suspicious with 0.3 probability. _END
# -
# Input sentence: ['1017 1018 5009 Credit 4923 1 Pakistan US USD 0.52 2012-10-26']
# Decoded sentence:  Transaction no 1018 is a credit transaction,performed on 2012-10-26, from Pakistan to US worth 4923 dollars, which is not suspicious with 0.52 probability. _END
# -
# Input sentence: ['1018 1019 5283 Credit 1485 0 India Germany INR 0.17 2025-07-21']
# Decoded sentence:  Transaction no 1019 is a credit transaction,performed on 2025-07-21, from India to Germany worth 1485 ruppees, which is suspicious with 0.17 probability. _END
# -
# Input sentence: ['1019 1020 5126 Debit 3962 0 Pakistan India INR 0.63 2008-05-13']
# Decoded sentence:  Transaction no 1020 is a debit transaction,performed on 2008-05-13, from Pakistan to India worth 3962 ruppees, which is suspicious with 0.63 probability. _END
# -
# Input sentence: ['1020 1021 5474 Credit 1852 1 India US USD 0.88 2020-02-13']
# Decoded sentence:  Transaction no 1021 is a credit transaction,performed on 2020-02-13, from India to US worth 1852 dollars, which is not suspicious with 0.88 probability. _END
# -
# Input sentence: ['1021 1022 5411 Credit 2935 1 Pakistan Germany Euro 0.49 2016-02-24']
# Decoded sentence:  Transaction no 1022 is a credit transaction,performed on 2016-02-24, from Pakistan to Germany worth 2935 euros, which is not suspicious with 0.49 probability. _END
# -
# Input sentence: ['1022 1023 5101 Credit 2705 1 India India INR 0.68 2017-07-16']
# Decoded sentence:  Transaction no 1023 is a credit transaction,performed on 2017-07-16, within India worth 2705 ruppees, which is not suspicious with 0.68 probability. _END
# -
# Input sentence: ['1023 1024 5334 Credit 978 1 Pakistan Japan Euro 0.17 2015-08-16']
# Decoded sentence:  Transaction no 1024 is a credit transaction,performed on 2015-08-16, from Pakistan to Japan worth 978 euros, which is not suspicious with 0.17 probability. _END
# -
# Input sentence: ['1024 1025 5157 Credit 4337 0 US India INR 0.12 2009-05-20']
# Decoded sentence:  Transaction no 1025 is a credit transaction,performed on 2009-05-20, from US to India worth 4337 ruppees, which is suspicious with 0.12 probability. _END
# -
# Input sentence: ['1025 1026 5058 Debit 4776 0 India India INR 0.71 2021-01-02']
# Decoded sentence:  Transaction no 1026 is a debit transaction,performed on 2021-01-02, within India worth 4776 ruppees, which is suspicious with 0.71 probability. _END
# -
# Input sentence: ['1026 1027 5073 Credit 8782 0 Japan China Yen 0.93 2007-05-18']
# Decoded sentence:  Transaction no 1027 is a credit transaction,performed on 2007-05-18, from Japan to China worth 8782 yen, which is suspicious with 0.93 probability. _END
# -
# Input sentence: ['1027 1028 5181 Debit 3363 1 Pakistan US USD 0.41 2022-11-26']
# Decoded sentence:  Transaction no 1028 is a debit transaction,performed on 2022-11-26, from Pakistan to US worth 3363 dollars, which is not suspicious with 0.41 probability. _END
# -
# Input sentence: ['1028 1029 5001 Debit 6017 1 India Germany INR 0.25 2021-08-18']
# Decoded sentence:  Transaction no 1029 is a debit transaction,performed on 2021-08-18, from India to Germany worth 6017 ruppees, which is not suspicious with 0.25 probability. _END
# -
# Input sentence: ['1029 1030 5049 Credit 7395 1 Pakistan India INR 0.19 2020-11-21']
# Decoded sentence:  Transaction no 1030 is a credit transaction,performed on 2020-11-21, from Pakistan to India worth 4781 ruppees, which is not suspicious with 0.92 probability. _END
# -
# Input sentence: ['1030 1031 5156 Credit 3960 1 India US USD 0.53 2006-11-08']
# Decoded sentence:  Transaction no 1031 is a credit transaction,performed on 2006-11-08, from India to US worth 3960 dollars, which is not suspicious with 0.53 probability. _END
# -
# Input sentence: ['1031 1032 5195 Debit 1106 1 Pakistan Germany Euro 0.93 2009-07-26']
# Decoded sentence:  Transaction no 1032 is a debit transaction,performed on 2009-07-26, from Pakistan to Germany worth 1106 euros, which is not suspicious with 0.93 probability. _END
# -
# Input sentence: ['1032 1033 5387 Debit 1121 1 India India INR 0.24 2020-06-14']
# Decoded sentence:  Transaction no 1033 is a debit transaction,performed on 2020-06-14, within India worth 1121 ruppees, which is not suspicious with 0.24 probability. _END
# -
# Input sentence: ['1033 1034 5383 Debit 2728 0 Pakistan Japan Euro 0.82 2022-02-03']
# Decoded sentence:  Transaction no 1034 is a debit transaction,performed on 2022-02-03, from Pakistan to Japan worth 2728 euros, which is suspicious with 0.82 probability. _END
# -
# Input sentence: ['1034 1035 5264 Credit 4746 0 US India INR 0.2 2019-05-26']
# Decoded sentence:  Transaction no 1035 is a credit transaction,performed on 2019-05-26, from US to India worth 4746 ruppees, which is suspicious with 0.2 probability. _END
# -
# Input sentence: ['1035 1036 5141 Debit 9013 1 India India INR 0.5 2023-09-28']
# Decoded sentence:  Transaction no 1036 is a debit transaction,performed on 2023-09-28, within India worth 9013 ruppees, which is not suspicious with 0.5 probability. _END
# -
# Input sentence: ['1036 1037 5163 Debit 1506 1 Japan China Yen 0.47 2010-01-13']
# Decoded sentence:  Transaction no 1037 is a debit transaction,performed on 2010-01-13, from Japan to China worth 1506 yen, which is not suspicious with 0.47 probability. _END
# -
# Input sentence: ['1037 1038 5028 Debit 2189 0 Pakistan US USD 0.61 2007-12-04']
# Decoded sentence:  Transaction no 1038 is a debit transaction,performed on 2007-12-04, from Pakistan to US worth 2189 dollars, which is suspicious with 0.61 probability. _END
# -
# Input sentence: ['1038 1039 5477 Credit 4480 1 India Germany INR 0.04 2022-07-16']
# Decoded sentence:  Transaction no 1039 is a credit transaction,performed on 2022-07-16, from India to Germany worth 4480 ruppees, which is not suspicious with 0.04 probability. _END
# -
# Input sentence: ['1039 1040 5123 Debit 2371 1 Pakistan India INR 0.1 2005-06-04']
# Decoded sentence:  Transaction no 1040 is a debit transaction,performed on 2005-06-04, from Pakistan to India worth 2371 ruppees, which is not suspicious with 0.1 probability. _END
# -
# Input sentence: ['1040 1041 5033 Debit 7006 1 India US USD 0.82 2019-05-26']
# Decoded sentence:  Transaction no 1041 is a debit transaction,performed on 2019-05-26, from India to US worth 7006 dollars, which is not suspicious with 0.82 probability. _END
# -
# Input sentence: ['1041 1042 5197 Debit 4977 0 Pakistan Germany Euro 0.22 2008-05-11']
# Decoded sentence:  Transaction no 1042 is a debit transaction,performed on 2008-05-11, from Pakistan to Germany worth 4977 euros, which is suspicious with 0.22 probability. _END
# -
# Input sentence: ['1042 1043 5131 Credit 6892 1 India India INR 0.58 2018-10-04']
# Decoded sentence:  Transaction no 1043 is a credit transaction,performed on 2018-10-04, within India worth 6892 ruppees, which is not suspicious with 0.58 probability. _END
# -
# Input sentence: ['1043 1044 5267 Credit 7978 0 Pakistan Japan Euro 0.89 2015-01-20']
# Decoded sentence:  Transaction no 1044 is a credit transaction,performed on 2015-01-20, from Pakistan to Japan worth 7978 euros, which is suspicious with 0.89 probability. _END
# -
# Input sentence: ['1044 1045 5259 Debit 1926 1 US India INR 0.95 2020-05-13']
# Decoded sentence:  Transaction no 1045 is a debit transaction,performed on 2020-05-13, from US to India worth 1926 ruppees, which is not suspicious with 0.95 probability. _END
# -
# Input sentence: ['1045 1046 5415 Credit 7613 0 India India INR 0.65 2025-10-04']
# Decoded sentence:  Transaction no 1046 is a credit transaction,performed on 2025-10-04, within India worth 7613 ruppees, which is suspicious with 0.65 probability. _END
# -
# Input sentence: ['1046 1047 5420 Debit 4396 1 Japan China Yen 0.92 2014-09-20']
# Decoded sentence:  Transaction no 1047 is a debit transaction,performed on 2014-09-20, from Japan to China worth 4396 yen, which is not suspicious with 0.92 probability. _END
# -
# Input sentence: ['1047 1048 5409 Debit 1510 1 Pakistan US USD 0.51 2022-10-27']
# Decoded sentence:  Transaction no 1048 is a debit transaction,performed on 2022-10-27, from Pakistan to US worth 1510 dollars, which is not suspicious with 0.51 probability. _END
# -
# Input sentence: ['1048 1049 5252 Debit 4280 1 India Germany INR 0.61 2024-12-19']
# Decoded sentence:  Transaction no 1049 is a debit transaction,performed on 2024-12-19, from India to Germany worth 4280 ruppees, which is not suspicious with 0.61 probability. _END
# -
# Input sentence: ['1049 1050 5147 Credit 2413 0 Pakistan India INR 0.82 2014-01-01']
# Decoded sentence:  Transaction no 1050 is a credit transaction,performed on 2014-01-01, from Pakistan to India worth 2413 ruppees, which is suspicious with 0.82 probability. _END
